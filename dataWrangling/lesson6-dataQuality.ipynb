# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up. In the first exercise we want you to audit
the datatypes that can be found in some particular fields in the dataset.
The possible types of values can be:
- NoneType if the value is a string "NULL" or an empty string ""
- list, if the value starts with "{"
- int, if the value can be cast to int
- float, if the value can be cast to float, but CANNOT be cast to int.
   For example, '3.23e+07' should be considered a float because it can be cast
   as float but int('3.23e+07') will throw a ValueError
- 'str', for all other values

The audit_file function should return a dictionary containing fieldnames and a 
SET of the types that can be found in the field. e.g.
{"field1": set([type(float()), type(int()), type(str())]),
 "field2": set([type(str())]),
  ....
}
The type() function returns a type object describing the argument given to the 
function. You can also use examples of objects to create type objects, e.g.
type(1.1) for a float: see the test function below for examples.

Note that the first three rows (after the header row) in the cities.csv file
are not actual data points. The contents of these rows should note be included
when processing data types. Be sure to include functionality in your code to
skip over or detect these rows.
"""
import codecs
import csv
import json
import pprint
from collections import defaultdict

CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]



def audit_file(filename, fields):
    fieldtypes = defaultdict(set)

    # YOUR CODE HERE
    instances = [int, float, str, type(None)]

    with open(filename) as f:
        reader = csv.DictReader(f)
        next(reader)
        for row in reader: 
            for field in fields:
                if row[field] == "NULL" or "":
                    fieldtypes[field].add(type(None))
                elif row[field].startswith("{"):
                    fieldtypes[field].add(list)
                elif row[field].isnumeric() and int(row[field]) is True:
                    fieldtypes[field].add(int)
                elif float(row[field]) is True and int(row[field]) is False:
                    fieldtypes[field].add(float)
                else: 
                    fieldtypes[field].add(str)
       
    return fieldtypes


def test():
    fieldtypes = audit_file(CITIES, FIELDS)

    pprint.pprint(fieldtypes)

    assert fieldtypes["areaLand"] == set([type(1.1), type([]), type(None)])
    assert fieldtypes['areaMetro'] == set([type(1.1), type(None)])
    
if __name__ == "__main__":
    test()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-100-f2370437e26a> in <module>()
#      78
#      79 if __name__ == "__main__":
# ---> 80     test()
#
# <ipython-input-100-f2370437e26a> in test()
#      70
#      71 def test():
# ---> 72     fieldtypes = audit_file(CITIES, FIELDS)
#      73
#      74     pprint.pprint(fieldtypes)
#
# <ipython-input-100-f2370437e26a> in audit_file(filename, fields)
#      50     instances = [int, float, str, type(None)]
#      51
# ---> 52     with open(filename) as f:
#      53         reader = csv.DictReader(f)
#      54         next(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cities.csv'

# %%
int('XMLSchema#string') is True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-4d7e4248f19e> in <module>()
# ----> 1 int('XMLSchema#string') is True
#
# ValueError: invalid literal for int() with base 10: 'XMLSchema#string'

# %%
a = "Kud"

# %%
"Kud".isnumeric()
# Out:
# False

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-8b2ab3991dae> in <module>()
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'Kud'

# %%
float('3.23e+07')
# Out:
# 32300000.0

# %%
a = '3.23e+07'

# %%
type(a)
# Out:
# str

# %%
float(a)
# Out:
# 32300000.0

# %%
int(float(a))
# Out:
# 32300000

# %%
float("Kud")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-83d98a4f51c0> in <module>()
# ----> 1 float("Kud") is True
#
# ValueError: could not convert string to float: 'Kud'

# %%
a.isnumeric()
# Out:
# False

# %%
a.isalpha()
# Out:
# False

# %%
a = "Indian Standard Time"
b = "Kud"
a.isalpha()
# Out:
# False

# %%
b.isalpha()
# Out:
# True

# %%
from decimal import Decimal

'%.2E' % Decimal('40800000000.00000000000000')

# returns '4.08E+10
# Out:
# '4.08e+10'

# %%
a
# Out:
# '3.23e+07'

# %%
b = "Indian Standard Time"
b.replace(" ", "")
# Out:
# 'IndianStandardTime'

# %%
repr(a)
# Out:
# "'a'"

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up. In the first exercise we want you to audit
the datatypes that can be found in some particular fields in the dataset.
The possible types of values can be:
- NoneType if the value is a string "NULL" or an empty string ""
- list, if the value starts with "{"
- int, if the value can be cast to int
- float, if the value can be cast to float, but CANNOT be cast to int.
   For example, '3.23e+07' should be considered a float because it can be cast
   as float but int('3.23e+07') will throw a ValueError
- 'str', for all other values

The audit_file function should return a dictionary containing fieldnames and a 
SET of the types that can be found in the field. e.g.
{"field1": set([type(float()), type(int()), type(str())]),
 "field2": set([type(str())]),
  ....
}
The type() function returns a type object describing the argument given to the 
function. You can also use examples of objects to create type objects, e.g.
type(1.1) for a float: see the test function below for examples.

Note that the first three rows (after the header row) in the cities.csv file
are not actual data points. The contents of these rows should note be included
when processing data types. Be sure to include functionality in your code to
skip over or detect these rows.
"""
import codecs
import csv
import json
import pprint
import re
from collections import defaultdict


CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]

def audit_file(filename, fields):
    fieldtypes = defaultdict(set)

    # YOUR CODE HERE

    with open(filename) as f:
        reader = csv.DictReader(f)
        next(reader)
        next(reader)
        next(reader)
        for row in reader: 
            for field in fields:
 
                if row[field] == "NULL" or "":
                    fieldtypes[field].add(type(None))
                    
                elif row[field].startswith("{"):
                    fieldtypes[field].add(list)
                    print(field, row[field])
                else:
                    try: 
                        int(row[field]) is True
                        fieldtypes[field].add(int)
                            
                    except:
                        try: 
                            float(row[field]) is True
                            fieldtypes[field].add(float) 
                        except:
                            fieldtypes[field].add(str)
                            
                    else:  
                        try:
                            float(row[field]) is True
                            fieldtypes[field].add(float) 
                        except: 
                            fieldtypes[field].add(str)
              
    print(fieldtypes['areaMetro'])
    
    return fieldtypes

# %%
def test():
    fieldtypes = audit_file(CITIES, FIELDS)

    pprint.pprint(fieldtypes, indent=3)

    assert fieldtypes["areaLand"] == set([type(1.1), type([]), type(None)])
    assert fieldtypes['areaMetro'] == set([type(1.1), type(None)])
    
if __name__ == "__main__":
    test()
# Out:
# isPartOf_label {Jammu and Kashmir|Udhampur district}
# isPartOf_label {Jharkhand|Ramgarh district}
# isPartOf_label {Guna district|Madhya Pradesh}
# isPartOf_label {Chhattisgarh|Durg district}
# name {Kundagola|Kundgol ಕುಂದಗೋಳ}
# isPartOf_label {Dharwad district|Karnataka}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Baramulla district|Jammu and Kashmir}
# name {Kurduvadi|कुर्डुवाडी}
# isPartOf_label {Maharashtra|Solapur district}
# isPartOf_label {Gulbarga district|Karnataka}
# isPartOf_label {Cuddalore district|Tamil Nadu}
# isPartOf_label {Chhattisgarh|Dhamtari district}
# isPartOf_label {Karnataka|Koppal district}
# name {Ladnun|लाडनूँ}
# isPartOf_label {Nagaur district|Rajasthan}
# name {Lahar|लहार}
# isPartOf_label {Bhind district|Madhya Pradesh}
# isPartOf_label {Sitapur district|Uttar Pradesh}
# isPartOf_label {Bundi district|Rajasthan}
# isPartOf_label {Assam|Cachar district}
# name {Laksar|लक्सर}
# isPartOf_label {Haridwar district|Uttarakhand}
# isPartOf_label {Nainital district|Uttarakhand}
# isPartOf_label {Dausa district|Rajasthan}
# name {Landhaura|लन्दौरा}
# isPartOf_label {Haridwar district|Uttarakhand}
# isPartOf_label {Maharashtra|Ratnagiri district}
# isPartOf_label {Maharashtra|Nashik district}
# isPartOf_label {Karnataka|Raichur|Raichur district}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Rajasthan|Sikar district}
# isPartOf_label {Chhattisgarh|Mungeli_District_Chhattisgarh}
# name {Machalpur|मचलपुर}
# isPartOf_label {Madhya Pradesh|Rajgarh district}
# name {Macherla|మాచెర్ల}
# isPartOf_label {Andhra Pradesh|Guntur district}
# isPartOf_label {Ludhiana district|Punjab India}
# isPartOf_label {Jaunpur district|Uttar Pradesh}
# isPartOf_label {Kanchipuram district|Tamil Nadu}
# name {Madanpur|মদনপুর}
# isPartOf_label {Nadia district|West Bengal}
# isPartOf_label {Hardoi district|Uttar Pradesh}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Deoghar district|Jharkhand}
# isPartOf_label {Budgam district|Jammu and Kashmir}
# isPartOf_label {Mathura district|Uttar Pradesh}
# isPartOf_label {Gujarat|Kheda district}
# isPartOf_label {Sitapur district|Uttar Pradesh}
# name {Mahudha|મહુધા}
# isPartOf_label {Gujarat|Kheda district}
# isPartOf_label {Maharashtra|Solapur district}
# isPartOf_label {Meghalaya|West Khasi Hills district}
# isPartOf_label {Amritsar district|Punjab India}
# isPartOf_label {Madhya Pradesh|Shajapur}
# isPartOf_label {Assam|Tinsukia district}
# name {Malavalli|Malavalli ಮಳವಳ್ಳಿ}
# isPartOf_label {Karnataka|Mandya district}
# isPartOf_label {Lucknow district|Uttar Pradesh}
# wgs84_pos#lat {26.92|26.94}
# isPartOf_label {Buldhana district|Maharashtra}
# wgs84_pos#lat {20.52|20.536}
# wgs84_pos#long {76.1124|76.12}
# isPartOf_label {Kolhapur district|Maharashtra}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Salem district|Tamil Nadu}
# isPartOf_label {Rajasthan|Tonk district}
# name {Manamadurai|மானாமதுரை}
# isPartOf_label {Sivaganga district|Tamil Nadu}
# isPartOf_label {Dhar district|Madhya Pradesh}
# name {Manchar|मंचर}
# isPartOf_label {Maharashtra|Pune district}
# isPartOf_label {Bhilwara district|Rajasthan}
# isPartOf_label {Ramanathapuram district|Tamil Nadu}
# isPartOf_label {Dausa district|Rajasthan}
# isPartOf_label {Jabalpur district|Madhya Pradesh}
# isPartOf_label {Madhya Pradesh|Rewa District}
# isPartOf_label {Gujarat|Junagadh district}
# name {Mangrol|aakash khandelwal}
# isPartOf_label {Baran district|Rajasthan}
# isPartOf_label {Beed district|Maharashtra}
# isPartOf_label {Assam|Dhubri district}
# isPartOf_label {Dharmapuri district|Tamil Nadu}
# isPartOf_label {Jaunpur district|Uttar Pradesh}
# name {Masaurhi|मसौढ़ी}
# isPartOf_label {Bihar|Patna district}
# wgs84_pos#lat {25.21|25.35}
# wgs84_pos#long {85.02|85.0333}
# name {Mataundh|Mataundh Banda Uttar Pradesh}
# isPartOf_label {Banda district|Uttar Pradesh}
# name {Mathabhanga|মাথাভাঙ্গা}
# isPartOf_label {Cooch Behar district|West Bengal}
# name {Maudaha|Maudaha (ragaul)}
# isPartOf_label {Hamirpur district Uttar Pradesh|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Rewa District}
# isPartOf_label {Imphal West district|Manipur}
# isPartOf_label {Gujarat|Sabarkantha district}
# isPartOf_label {Azamgarh district|Uttar Pradesh}
# name {Mekhliganj|মেখলিগঞ্জ}
# isPartOf_label {Cooch Behar district|West Bengal}
# isPartOf_label {Rampur district|Uttar Pradesh}
# name {Mihona|मिहोना}
# isPartOf_label {Bhind district|Madhya Pradesh}
# isPartOf_label {Gujarat|Jamnagar district}
# name {मोहनपुर मोहम्मदपुर|Mohanpur Mohammadpur}
# isPartOf_label {Haridwar district|Uttarakhand}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Assam|Dibrugarh district}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# isPartOf_label {Bijapur district Karnataka|Karnataka}
# isPartOf_label {Chikkamagaluru district|Karnataka}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Farrukhabad district|Uttar Pradesh}
# name {Mukundgarh|मुकुंदगढ़}
# isPartOf_label {Jhunjhunu district|Rajasthan}
# isPartOf_label {Hoshiarpur district|Punjab India}
# isPartOf_label {Chandrapur district|Maharashtra}
# name {Shri Muktsar Sahib|ਸ੍ਰੀ ਮੁਕਤਸਰ ਸਾਹਿਬ}
# isPartOf_label {Shrimuktsarsahib_Shri_Muktsar_Sahib%5D_district|Punjab India}
# isPartOf_label {Betul district|Madhya Pradesh}
# name {Mundgod|ಮುಂಡಗೋಡು}
# isPartOf_label {Karnataka|Uttara Kannada}
# name {Marwar Mundwa|Mundwa}
# isPartOf_label {Nagaur district|Rajasthan}
# isPartOf_label {Ashoknagar district|Madhya Pradesh}
# isPartOf_label {Chhattisgarh|Mungeli_District_Chhattisgarh}
# isPartOf_label {Ghaziabad district India|Uttar Pradesh}
# isPartOf_label {Maharashtra|Thane district}
# name {Murgud|मुरगुड}
# isPartOf_label {Kolhapur district|Maharashtra}
# isPartOf_label {Maharashtra|Raigad district}
# isPartOf_label {Maharashtra|Osmanabad district}
# isPartOf_label {East Singhbhum district|Jharkhand}
# isPartOf_label {Amethi district|Uttar Pradesh}
# wgs84_pos#lat {26.37|26.45}
# name {Nabadwip|নবদ্বীপ}
# isPartOf_label {Nadia district|West Bengal}
# isPartOf_label {Ahmednagar district|Maharashtra}
# name {Nagothana|नागोठणे}
# isPartOf_label {Maharashtra|Raigad district}
# name {Nagram|Nal Gram}
# isPartOf_label {Lucknow district|Uttar Pradesh}
# name {Naharkatiya|নাহৰকটীয়া}
# isPartOf_label {Assam|Dibrugarh district}
# name {Nainwa|नैन्वा}
# isPartOf_label {Bundi district|Rajasthan}
# isPartOf_label {Kanyakumari district|Tamil Nadu}
# isPartOf_label {Erode district|Tamil Nadu}
# isPartOf_label {Bishnupur district|Manipur}
# isPartOf_label {Madhya Pradesh|Ratlam district}
# isPartOf_label {Saharanpur district|Uttar Pradesh}
# isPartOf_label {Chamoli district|Uttarakhand}
# isPartOf_label {Maharashtra|Nandurbar district}
# name {Nangavalli|நங்கவள்ளி}
# isPartOf_label {Salem district|Tamil Nadu}
# name {Nanguneri|நாங்குநேரி}
# isPartOf_label {Tamil Nadu|Tirunelveli district}
# isPartOf_label {Bahraich district|Uttar Pradesh}
# isPartOf_label {Chikkamagaluru district|Karnataka}
# isPartOf_label {Moradabad district|Uttar Pradesh}
# isPartOf_label {Tamil Nadu|Tiruvallur district}
# isPartOf_label {Andhra Pradesh|Chittoor district}
# name {Narendra Nagar|नरेन्द्र नगर}
# isPartOf_label {Tehri Garhwal district|Uttarakhand}
# name {Naregal|Naregal Gadag}
# isPartOf_label {Gadag district|Karnataka}
# name {Naragunda ನರಗುಂದ|Nargund}
# isPartOf_label {Gadag district|Karnataka}
# name {Narwana|thumbnail}
# isPartOf_label {Haryana|Jind district}
# wgs84_pos#long {76.1117|76.1167}
# isPartOf_label {Adilabad district|Andhra Pradesh}
# wgs84_pos#lat {18.83|18.8604}
# wgs84_pos#long {79.45|79.4849}
# isPartOf_label {Sivaganga district|Tamil Nadu}
# name {Navalagunda|Navalgund ನವಲಗುಂದ}
# isPartOf_label {Dharwad district|Karnataka}
# utcOffset {+5.30|+5:30}
# isPartOf_label {Tamil Nadu|Tiruchirappalli district}
# wgs84_pos#lat {10.7375|10.7425}
# wgs84_pos#long {78.7667|78.7672}
# name {Nawa|Nawa Rajasthan}
# isPartOf_label {Nagaur district|Rajasthan}
# name {Nawapur|नवापूर}
# isPartOf_label {Maharashtra|Nandurbar district}
# isPartOf_label {Bijnor|Uttar Pradesh}
# isPartOf_label {Chennai|Tamil Nadu|Tiruvallur district}
# isPartOf_label {Dindigul district|Tamil Nadu}
# name {(Cement City)|NIMBAHERA}
# isPartOf_label {Chittorgarh district|Rajasthan}
# isPartOf_label {Dhanbad district|Jharkhand}
# name {Nizamabad|Nizamabad Uttar Pradesh}
# isPartOf_label {Azamgarh district|Uttar Pradesh}
# isPartOf_label {Hanumangarh district|Rajasthan}
# isPartOf_label {Bikaner district|Rajasthan}
# name {North Guwahati|উত্তৰ গুৱাহাটী}
# isPartOf_label {Assam|Kamrup district}
# isPartOf_label {Jammu and Kashmir|Rajouri district}
# wgs84_pos#lat {33.04|34.13}
# wgs84_pos#long {74.14|74.8}
# isPartOf_label {Himachal Pradesh|Kangra district}
# name {Nuh|Nuh India}
# isPartOf_label {HaLink_titleryana|Mewat}
# isPartOf_label {Sonbhadra district|Uttar Pradesh}
# name {Oran|Oran India}
# isPartOf_label {Banda district|Uttar Pradesh}
# name {Pachora|पाचोरा}
# isPartOf_label {Jalgaon district|Maharashtra}
# isPartOf_label {Balrampur district|Uttar Pradesh}
# name {Padampur|पदमपुर}
# isPartOf_label {Rajasthan|Sri Ganganagar district}
# name {Paddhari|પડધરી}
# isPartOf_label {Gujarat|Rajkot district}
# isPartOf_label {Bargarh district|Odisha}
# isPartOf_label {Bulandshahr district|Uttar Pradesh}
# isPartOf_label {Dharmapuri district|Tamil Nadu}
# isPartOf_label {Madurai district|Tamil Nadu}
# name {Palasbari|পলাশবাৰী}
# isPartOf_label {Assam|Kamrup district}
# name {Palayam|Palayam Kanyakumari}
# isPartOf_label {Dindigul district|Tamil Nadu}
# isPartOf_label {Madhya Pradesh|Tikamgarh district}
# isPartOf_label {Jabalpur district|Madhya Pradesh}
# isPartOf_label {Jammu and Kashmir|Pulwama district}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# name {Pandavapura|Pandavapura ಪಾಂಡವಪುರ}
# isPartOf_label {Karnataka|Mandya district}
# isPartOf_label {Khandwa district|Madhya Pradesh}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Barwani district|Madhya Pradesh}
# wgs84_pos#lat {21.65|21.66}
# name {Pappinisseri|പാപ്പിനിശ്ശേരി‍}
# isPartOf_label {Kannur district|Kerala}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# name {Parole|Parole India}
# isPartOf_label {Jammu and Kashmir|Kathua district}
# name {Partur|परतूर}
# isPartOf_label {Jalna district|Maharashtra}
# isPartOf_label {Andhra Pradesh|Medak district}
# isPartOf_label {Chhattisgarh|Jashpur district}
# isPartOf_label {Ahmednagar district|Maharashtra}
# isPartOf_label {Maharashtra|Parbhani district}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Balangir district|Odisha}
# isPartOf_label {Jharkhand|Ramgarh district}
# name {Patur|पातूर}
# isPartOf_label {Akola district|Maharashtra}
# wgs84_pos#lat {20.45|20.46}
# wgs84_pos#long {76.93|76.94}
# isPartOf_label {Bhandara district|Maharashtra}
# isPartOf_label {Madhya Pradesh|Panna district}
# isPartOf_label {Haryana|Kurukshetra district}
# isPartOf_label {Bilaspur district Chhattisgarh|Chhattisgarh}
# isPartOf_label {Cuddalore district|Tamil Nadu}
# isPartOf_label {Dharmapuri district|Tamil Nadu}
# isPartOf_label {Madurai district|Tamil Nadu}
# isPartOf_label {Tamil Nadu|Thanjavur district}
# isPartOf_label {Tamil Nadu|Theni district}
# wgs84_pos#lat {10.07|10.12}
# wgs84_pos#long {77.33|77.55}
# isPartOf_label {Tamil Nadu|Tirupur district}
# name {Pedne / पेडणें|Pernem}
# isPartOf_label {Goa|North Goa|Pernem taluk}
# isPartOf_label {Jhabua district|Madhya Pradesh}
# isPartOf_label {Meerut district|Uttar Pradesh}
# isPartOf_label {Jaipur district|Rajasthan}
# name {Phulpur|Phulpur Azamgarh}
# isPartOf_label {Azamgarh district|Uttar Pradesh}
# name {Phulwari Sharif|फुलवारी शरीफ़}
# isPartOf_label {Bihar|Patna district}
# isPartOf_label {Hardoi district|Uttar Pradesh}
# isPartOf_label {Hanumangarh district|Rajasthan}
# isPartOf_label {Odisha|Puri district}
# isPartOf_label {Sonbhadra district|Uttar Pradesh}
# isPartOf_label {Gorakhpur district|Uttar Pradesh}
# isPartOf_label {Jhalawar district|Rajasthan}
# isPartOf_label {Chhattisgarh|Mahasamund district}
# isPartOf_label {Ganjam district|Odisha}
# isPartOf_label {Tamil Nadu|Tiruvallur district}
# isPartOf_label {Madhya Pradesh|Morena district}
# isPartOf_label {Ramabai Nagar district|Uttar Pradesh}
# isPartOf_label {Karur district|Tamil Nadu}
# name {Punganur|పుంగనూరు}
# isPartOf_label {Andhra Pradesh|Chittoor district}
# isPartOf_label {Maharashtra|Parbhani district}
# isPartOf_label {Unnao district|Uttar Pradesh}
# isPartOf_label {Gautam Buddh Nagar district|Uttar Pradesh}
# isPartOf_label {Aurangabad district Bihar|Bihar}
# name {Raghunathpur|रघुनाथपुर}
# isPartOf_label {Bihar|Buxar district}
# isPartOf_label {Punjab India|Shahid Bhagat Singh Nagar district}
# isPartOf_label {Madhya Pradesh|Sagar district}
# isPartOf_label {Ludhiana district|Punjab India}
# isPartOf_label {Ahmednagar district|Maharashtra}
# isPartOf_label {Dholpur district|Rajasthan}
# isPartOf_label {Churu district|Rajasthan}
# name {Rajauri|Rajouri}
# isPartOf_label {Jammu and Kashmir|Rajouri district}
# isPartOf_label {Barwani district|Madhya Pradesh}
# name {Rajpur Sonarpur|রাজপুর সোনারপুর}
# isPartOf_label {South 24 Parganas district|West Bengal}
# wgs84_pos#lat {22.41|22.42}
# name {Rajura|राजुरा}
# isPartOf_label {Chandrapur district|Maharashtra}
# isPartOf_label {Kushinagar district|Uttar Pradesh}
# isPartOf_label {Andhra Pradesh|East Godavari district}
# isPartOf_label {Jhabua district|Madhya Pradesh}
# isPartOf_label {Maharashtra|Nagpur district}
# isPartOf_label {Gujarat|Porbandar district}
# name {Ranbir Singh Pora|Ranbir Singh Pura}
# isPartOf_label {Jammu and Kashmir|Jammu district}
# name {Rani|राणी}
# isPartOf_label {Pali district|Rajasthan}
# name {Raniganj|রাণীগঞ্জ}
# isPartOf_label {Bardhaman district|West Bengal}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# isPartOf_label {Gujarat|Kutch District}
# isPartOf_label {Ballia district|Uttar Pradesh}
# isPartOf_label {Unnao district|Uttar Pradesh}
# isPartOf_label {Fatehabad district|Haryana}
# isPartOf_label {Hanumangarh district|Rajasthan}
# isPartOf_label {Andhra Pradesh|YSR district}
# isPartOf_label {Jammu and Kashmir|Reasi district}
# isPartOf_label {Madhya Pradesh|Sagar district}
# isPartOf_label {Madhya Pradesh|Sehore district}
# name {Renigunta|Tirupati-Renigunta}
# isPartOf_label {Andhra Pradesh|Chittoor district}
# isPartOf_label {Bareilly district|Uttar Pradesh}
# isPartOf_label {Himachal Pradesh|Shimla district}
# name {Ron|ರೋಣ}
# isPartOf_label {Gadag district|Haveri|Karnataka}
# name {Rudauli|Rudauli naveen}
# isPartOf_label {Faizabad district|Uttar Pradesh}
# name {Rudraprayag|रुद्र प्रयाग}
# isPartOf_label {Rudraprayag district|Uttarakhand}
# isPartOf_label {Ramabai Nagar district|Uttar Pradesh}
# name {Sabalgarh|सबलगढ़}
# isPartOf_label {Madhya Pradesh|Morena district}
# isPartOf_label {South Tripura district|Tripura}
# isPartOf_label {Hathras district|Uttar Pradesh}
# isPartOf_label {Belgaum district|Karnataka}
# name {Sadri|सादड़ी}
# isPartOf_label {Pali district|Rajasthan}
# isPartOf_label {Dungarpur district|Rajasthan}
# isPartOf_label {Bijnor district|Uttar Pradesh}
# name {Sahawar|Sahawar Town}
# isPartOf_label {Kashiram_Nagar|Uttar Pradesh}
# name {Saidpur|Saidpur Badaun}
# isPartOf_label {Budaun district|Uttar Pradesh}
# name {Sailu|सेलू}
# isPartOf_label {Maharashtra|Parbhani district}
# wgs84_pos#lat {19.442|19.47}
# wgs84_pos#long {76.429|76.47}
# isPartOf_label {Aizawl district|Mizoram}
# name {Sakleshpur|ಸಕಲೇಶಪುರ}
# isPartOf_label {Hassan district|Karnataka}
# isPartOf_label {Dwarka_district|Gujarat}
# isPartOf_label {Andhra Pradesh|Vizianagaram district}
# isPartOf_label {Rajasthan|Udaipur district}
# isPartOf_label {Haryana|Panipat}
# isPartOf_label {Ludhiana district|Punjab India}
# areaCode {01628|postal_code = 141114|vehicle_code_range =}
# isPartOf_label {Patiala district|Punjab India}
# isPartOf_label {Khargone district|Madhya Pradesh}
# name {Sandi|Sandi Uttar Pradesh}
# isPartOf_label {Hardoi district|Uttar Pradesh}
# isPartOf_label {Hardoi district|Uttar Pradesh}
# name {Sangamner|संगमनेर}
# isPartOf_label {Ahmednagar district|Maharashtra}
# isPartOf_label {Kota district|Rajasthan}
# isPartOf_label {Himachal Pradesh|Una district}
# isPartOf_label {Assam|Dhubri district}
# isPartOf_label {Chhattisgarh|Mahasamund district}
# isPartOf_label {Madhya Pradesh|Rajgarh district}
# isPartOf_label {Assam|Dibrugarh district}
# isPartOf_label {Ajmer district|Rajasthan}
# isPartOf_label {Barabanki district|Uttar Pradesh}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Kannauj district|Uttar Pradesh}
# isPartOf_label {Jalgaon district|Maharashtra}
# isPartOf_label {Bijnor district|Uttar Pradesh}
# isPartOf_label {Datia district|Madhya Pradesh}
# isPartOf_label {Maharashtra|Thane district}
# isPartOf_label {Madhya Pradesh|Sagar district}
# name {Shahkot|ਸ਼ਾਹਕੋਟ}
# isPartOf_label {Jalandhar district|Punjab India}
# isPartOf_label {Shamli district|Uttar Pradesh}
# wgs84_pos#lat {29.4481|29.45}
# wgs84_pos#long {77.3103|77.32}
# name {Shamsabad|Shamsabad Agra}
# isPartOf_label {Agra district|Uttar Pradesh}
# isPartOf_label {Bijnor district|Uttar Pradesh}
# isPartOf_label {Maharashtra|Satara district}
# isPartOf_label {Bareilly district|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Shajapur district}
# isPartOf_label {Etah district|Uttar Pradesh}
# isPartOf_label {Jabalpur district|Madhya Pradesh}
# wgs84_pos#lat {23.0|23.48}
# name {Sihor|સિહોર}
# isPartOf_label {Bhavnagar district|Gujarat}
# wgs84_pos#lat {21.4253|21.7}
# wgs84_pos#long {71.5736|71.97}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Chhattisgarh|Raipur district}
# isPartOf_label {Bijapur district Karnataka|Karnataka}
# isPartOf_label {Madhya Pradesh|Neemuch district}
# name {Singtam|सिंगताम}
# isPartOf_label {East Sikkim district|Sikkim}
# name {Sinnar|सिन्नर}
# isPartOf_label {Maharashtra|Nashik district}
# name {Shiralakoppa|Siralkoppa}
# isPartOf_label {Karnataka|Shimoga district}
# name {Sirsa|Sirsa Uttar Pradesh}
# isPartOf_label {Allahabad district|Uttar Pradesh}
# name {Sirsi|Sirsi Sadat}
# isPartOf_label {Sambhal district|Uttar Pradesh}
# name {Siraguppa|Siruguppa}
# isPartOf_label {Bellary district|Karnataka}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# isPartOf_label {Hoshangabad district|Madhya Pradesh}
# name {Sohna|सोहना}
# isPartOf_label {Gurgaon district|Haryana}
# isPartOf_label {Pali district|Rajasthan}
# name {Sompeta|సోంపేట}
# isPartOf_label {Andhra Pradesh|Srikakulam district}
# isPartOf_label {Gujarat|Tapi district}
# isPartOf_label {Karnataka|Sagara Shimoga district}
# name {South Dumdum|দক্ষিণ দমদম}
# isPartOf_label {North 24 Parganas district|West Bengal}
# isPartOf_label {Kasganj district|Uttar Pradesh}
# name {Srinivasapura|Srinivaspur}
# isPartOf_label {Karnataka|Kolar district}
# name {Sualkuchi|শুৱালকুছি}
# isPartOf_label {Assam|Kamrup district}
# isPartOf_label {Tamil Nadu|Virudhunagar district}
# isPartOf_label {Kota district|Rajasthan}
# name {Sunam|Sunam Udham Singh Wala}
# isPartOf_label {Punjab India|Sangrur district}
# isPartOf_label {Jammu and Kashmir|Rajouri district}
# name {Sundar Nagar|सुंदर नगर}
# isPartOf_label {Himachal Pradesh|Mandi district}
# isPartOf_label {Jhunjhunu district|Rajasthan}
# isPartOf_label {Tamil Nadu|Tirunelveli district}
# name {Suratgarh|सूरतगढ़}
# isPartOf_label {Rajasthan|Sri Ganganagar district}
# isPartOf_label {Madhya Pradesh|Shajapur district}
# isPartOf_label {Anantapur district|Andhra Pradesh}
# isPartOf_label {Bilaspur district Chhattisgarh|Chhattisgarh}
# name {Talaja Gujarat India|તળાજા}
# isPartOf_label {Bhavnagar district|Gujarat}
# isPartOf_label {Kannauj district|Uttar Pradesh}
# isPartOf_label {Hoshiarpur district|Punjab India}
# wgs84_pos#lat {31.9|31.95}
# wgs84_pos#long {75.65|75.87}
# name {Tanakpur|टनकपुर}
# isPartOf_label {Champawat district|Uttarakhand}
# name {Tanda|Tanda Rampur}
# isPartOf_label {Rampur district|Uttar Pradesh}
# isPartOf_label {Maharashtra|Sangli district}
# isPartOf_label {Gwalior district|Madhya Pradesh}
# isPartOf_label {Madhya Pradesh|Rewa District}
# isPartOf_label {Moradabad district|Uttar Pradesh}
# isPartOf_label {Jammu and Kashmir|Rajouri district}
# isPartOf_label {Jhabua district|Madhya Pradesh}
# name {Tharamangalam|தாரமங்கலம்}
# isPartOf_label {Salem district|Tamil Nadu}
# isPartOf_label {Tamil Nadu|Thanjavur district}
# name {திருத்துறைப்பூண்டி|Thiruthuraipoondi}
# isPartOf_label {Tamil Nadu|Tiruvarur district}
# isPartOf_label {Tamil Nadu|Thanjavur district}
# isPartOf_label {Manipur|Thoubal district}
# name {Tijara|तिजारा}
# isPartOf_label {Alwar district|Rajasthan}
# name {Tikri|Tikri Uttar Pradesh}
# isPartOf_label {Bagpat district|Uttar Pradesh}
# isPartOf_label {Banda district|Uttar Pradesh}
# isPartOf_label {Tamil Nadu|Viluppuram district}
# isPartOf_label {Hamirpur district Himachal Pradesh|Himachal Pradesh}
# name {Tipaturu|Tiptur}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Balaghat district|Madhya Pradesh}
# name {Titagarh|টিটাগড়}
# isPartOf_label {North 24 Parganas district|West Bengal}
# isPartOf_label {Saharanpur district|Uttar Pradesh}
# wgs84_pos#lat {29.668|29.67}
# wgs84_pos#long {77.32|77.323}
# isPartOf_label {Fatehabad district|Haryana}
# name {Trimbak|त्रिंबक}
# isPartOf_label {Maharashtra|Nashik district}
# name {Tufanganj|তুফানগঞ্জ}
# isPartOf_label {Cooch Behar district|West Bengal}
# isPartOf_label {Balrampur district|Uttar Pradesh}
# name {Tumsar|तुमसर}
# isPartOf_label {Bhandara district|Maharashtra}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Haryana|Jind district}
# name {Odalguri|ওদালগুৰি}
# isPartOf_label {Assam|Udalguri district}
# isPartOf_label {Kota district|Rajasthan}
# isPartOf_label {Budaun district|Uttar Pradesh}
# wgs84_pos#lat {28.02|28.35}
# isPartOf_label {Balaghat district|Madhya Pradesh}
# name {Uluberia|উলুবেড়িয়া}
# isPartOf_label {Howrah district|West Bengal}
# name {Umarga|उमरगा}
# isPartOf_label {Maharashtra|Osmanabad district}
# isPartOf_label {Maharashtra|Yavatmal district}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Ujjain district}
# isPartOf_label {Rajasthan|Tonk district}
# name {Unjha|Unjha(umapur)}
# isPartOf_label {Gujarat|Mehsana district}
# isPartOf_label {Gujarat|Rajkot district}
# name {Uravakonda|ఉరవకొండ}
# isPartOf_label {Anantapur district|Andhra Pradesh}
# isPartOf_label {Budaun district|Uttar Pradesh}
# isPartOf_label {Gujarat|Surat district}
# name {Uttar Durgapur|উত্তর দুর্গাপুর}
# isPartOf_label {South 24 Parganas district|West Bengal}
# isPartOf_label {Gujarat|Mehsana district}
# wgs84_pos#lat {23.78|23.785}
# wgs84_pos#long {72.63|72.64}
# name {Vaijapur|वैजापूर}
# isPartOf_label {Aurangabad district Maharashtra|Maharashtra}
# isPartOf_label {Goa|South Goa}
# isPartOf_label {Bhavnagar district|Gujarat}
# name {Vedasandur|வேடசந்தூர்}
# isPartOf_label {Dindigul district|Tamil Nadu}
# name {Veerbhadra|वीरभद्र}
# isPartOf_label {Dehradun district|Uttarakhand}
# isPartOf_label {Namakkal district|Tamil Nadu}
# wgs84_pos#lat {10.1|11.1}
# wgs84_pos#long {76.25|78.02}
# name {Vengathur|வெங்காத்தூர்}
# isPartOf_label {Tamil Nadu|Tiruvallur district}
# isPartOf_label {Gujarat|Mehsana district}
# isPartOf_label {Bangalore Rural district|Karnataka}
# isPartOf_label {Tamil Nadu|Tirunelveli district}
# isPartOf_label {Ahmedabad district|Gujarat}
# name {Thirumudhukundram|Virudhachalam}
# isPartOf_label {Cuddalore district|Tamil Nadu}
# isPartOf_label {Gujarat|Junagadh district}
# isPartOf_label {Gujarat|Mehsana district}
# name {Vyara|વ્યારા}
# isPartOf_label {Gujarat|Tapi district}
# isPartOf_label {Gujarat|Rajkot district}
# isPartOf_label {Budaun district|Uttar Pradesh}
# isPartOf_label {Bharatpur district|Rajasthan}
# name {Yalaburga|Yelburga}
# isPartOf_label {Karnataka|Koppal district}
# name {Yerraguntala|Yerraguntla}
# isPartOf_label {Andhra Pradesh|YSR district}
# isPartOf_label {Himachal Pradesh|Kangra district}
# name {Ech|Echt}
# utcOffset {+1|+2}
# isPartOf_label {Echt-Susteren|Limburg (Netherlands)}
# isPartOf_label {Himachal Pradesh|Kullu district}
# isPartOf_label {Chamba district|Himachal Pradesh}
# name {Seoni|Suni}
# isPartOf_label {Himachal Pradesh|Shimla district}
# isPartOf_label {Himachal Pradesh|Shimla district}
# isPartOf_label {Jos South|Plateau State}
# name {Pochutla|San Pedro Pochutla}
# wgs84_pos#lat {15.7333|15.7444}
# wgs84_pos#long {-96.4667|-96.4653}
# utcOffset {-5|-6}
# isPartOf_label {Alabama|Barbour County Alabama}
# wgs84_pos#lat {31.7814|31.885}
# wgs84_pos#long {-85.3022|-85.1539}
# name {City of Santa Clarita|Santa Clarita California}
# utcOffset {-7|-8}
# isPartOf_label {California|Los Angeles County California}
# elevation {367.894|368.0}
# wgs84_pos#lat {34.4166|34.4167}
# isPartOf_label {New York|Queens}
# name {Longhai|龙海|龙海市}
# isPartOf_label {Fujian|Zhangzhou}
# wgs84_pos#lat {24.3833|24.4}
# wgs84_pos#long {117.767|118.05}
# utcOffset {-5|-6}
# name {Aland|Gulbarga Karnataka}
# isPartOf_label {Gulbarga district|Karnataka}
# utcOffset {-5|-6}
# isPartOf_label {Hood County Texas|Texas}
# utcOffset {-5|-6}
# isPartOf_label {Hood County Texas|Texas}
# utcOffset {-5|-6}
# isPartOf_label {Hood County Texas|Johnson County Texas|Parker County Texas|Texas}
# utcOffset {-5|-6}
# isPartOf_label {Grimes County Texas|Texas}
# name {Aarani|ஆரணி}
# isPartOf_label {Tamil Nadu|Tiruvannamalai district}
# name {Ramgarh|रामगढ़ शेखावाटी}
# isPartOf_label {Rajasthan|Sikar district}
# wgs84_pos#lat {23.92|27.2506}
# wgs84_pos#long {73.95|75.1787}
# utcOffset {-5|-6}
# isPartOf_label {Texas|Travis County Texas}
# name {Phuket|Phuket Municipality|ภูเก็ต}
# isPartOf_label {Daman and Diu|Diu district}
# isPartOf_label {Merauke Regency|Papua (province)}
# name {Nuwar|Sorong}
# isPartOf_label {Jalgaon district|Maharashtra}
# utcOffset {-5|-6}
# isPartOf_label {Horokhiv Raion|Volyn Oblast}
# isPartOf_label {Cooch Behar district|West Bengal}
# wgs84_pos#lat {26.3242|26.3667}
# wgs84_pos#long {89.451|89.4833}
# utcOffset {-6|-7}
# isPartOf_label {Arapahoe County Colorado|Colorado|Douglas County Colorado|Jefferson County Colorado}
# elevation {1630.98|1631.0}
# populationDensity {1117.5|1120.55}
# areaLand {3.49648e+07|3.5e+07}
# isPartOf_label {East Java|Indonesia}
# name {Gorontalo City|Kota Gorontalo}
# isPartOf_label {Gorontalo (province)|Gorontalo Regency}
# name {Thành phố Việt Trì|Viet Tri}
# name {Tam Ky|Thành phố Tam Kỳ}
# name {Salamanca|Xidoo Place of Tepetate}
# wgs84_pos#lat {20.567|20.5703}
# wgs84_pos#long {-101.2|-101.197}
# name {Cam Pha|Thành phố Cẩm Phả}
# isPartOf_label {Northeast (Vietnam)|Quảng Ninh Province}
# name {Siem Reap|ក្រុងសៀមរាប}
# name {Kampong Thom|ក្រុងកំពង់ធំ}
# isPartOf_label {Kampong_Thom_District|Kampong Thom Province}
# name {Prey Veng|ក្រុងព្រៃវែង}
# isPartOf_label {Prey Veaeng District|Prey Veng Province}
# name {Kampong Chhnang|ក្រុងកំពង់ឆ្នាំង}
# isPartOf_label {Kampong Chhnang District|Kampong Chhnang Province}
# isPartOf_label {Hassan district|Karnataka}
# isPartOf_label {Durango|Mapimí Municipality}
# name {郡山|郡山市 · Kōriyama}
# name {いわき|いわき市 · Iwaki City}
# utcOffset {-5|-6}
# isPartOf_label {Hays County Texas|Texas}
# elevation {349.91|350.0}
# populationDensity {180.966|181.0}
# wgs84_pos#lat {30.1919|30.192}
# wgs84_pos#long {-98.0854|-98.0853}
# areaLand {8.54696e+06|8.6e+06}
# name {Prymorsk|Приморськ}
# name {Hlobyne|Глобине}
# wgs84_pos#lat {49.3667|49.3833}
# wgs84_pos#long {33.2667|33.2833}
# name {Komsomolsk|Комсомольськ}
# utcOffset {+5|+6}
# isPartOf_label {Lodhran District|Punjab Pakistan}
# name {Ganjam|ଗଞ୍ଜାମ}
# isPartOf_label {Ganjam district|Odisha}
# name {Fatehabad|Fatehabad Agra}
# isPartOf_label {Agra district|Uttar Pradesh}
# utcOffset {+4|+5}
# utcOffset {-5|-6}
# isPartOf_label {Tamil Nadu|Theni district}
# wgs84_pos#lat {9.31|9.68}
# wgs84_pos#long {77.2|77.27}
# isPartOf_label {Tamil Nadu|Theni district}
# isPartOf_label {Okara Pakistan|Punjab Pakistan}
# wgs84_pos#lat {30.41|30.6667}
# wgs84_pos#long {73.42|73.65}
# utcOffset {+2|+3}
# name {Mohanpur|Mohanpur Uttar Pradesh}
# isPartOf_label {Etah district|Uttar Pradesh}
# name {City of Von Ormy|Von Ormy Texas}
# utcOffset {-5|-6}
# populationDensity {228.1|228.148}
# isPartOf_label {Gujarat|Jamnagar district}
# name {Sivagiri|Sivagiri Erode}
# isPartOf_label {Erode district|Tamil Nadu}
# isPartOf_label {Tamil Nadu|Tirunelveli district}
# isPartOf_label {Gujarat|Surat district}
# isPartOf_label {Gujarat|Navsari district}
# isPartOf_label {Gujarat|Valsad district}
# isPartOf_label {Caribbean Region Colombia|Cesar department}
# wgs84_pos#lat {8.3125|8.31667}
# wgs84_pos#long {-73.6333|73.6269}
# isPartOf_label {Caribbean Region Colombia|Cesar department}
# wgs84_pos#long {-74.2333|-73.2333}
# isPartOf_label {Caribbean Region Colombia|Cesar department}
# name {Kadi|કડી}
# isPartOf_label {Gujarat|Mehsana district}
# wgs84_pos#lat {23.18|23.3009}
# wgs84_pos#long {72.2|72.3322}
# isPartOf_label {Amreli district|Gujarat}
# name {Puerto Armuelles|Rabo De Puerco}
# governmentType_label {City|Multiculturalism}
# isPartOf_label {Chiriquí Province|Pacific Ocean}
# isPartOf_label {Madhya Pradesh|Raisen district}
# name {Srinagar|श्रीनगर}
# isPartOf_label {Pauri Garhwal district|Uttarakhand}
# isPartOf_label {Dehradun district|Uttarakhand}
# name {Weinan|渭南市}
# homepage {http://top.weinan.gov.cn/en|http://www.weinan.gov.cn}
# name {Mahis|مدينة ماحص}
# utcOffset {+2|+3}
# name {Bally|Bally Howrah}
# isPartOf_label {Howrah district|West Bengal}
# isPartOf_label {Nainital district|Uttarakhand}
# name {Brugh Thuinne|Churchtown}
# timeZone_label {Time in the Republic of Ireland|Western European Time}
# utcOffset {+0|-1}
# isPartOf_label {County Cork|Munster}
# isPartOf_label {New York|Queens}
# isPartOf_label {Guna district|Madhya Pradesh}
# name {Munchon|문천|문천시}
# name {Songnim|송림|송림시}
# name {Faridpur|Faridpur Uttar Pradesh}
# isPartOf_label {Bareilly district|Uttar Pradesh}
# name {Hilsa|हिलसा}
# isPartOf_label {Bihar|Nalanda district}
# name {Manpo|만포|만포시}
# isPartOf_label {Jammu and Kashmir|Poonch district India}
# name {Sinpo|신포|신포시}
# name {Rath|Rath India}
# isPartOf_label {Bundelkhand|Chitrakoot division|Hamirpur district Uttar Pradesh|Uttar Pradesh}
# name {Shu|Шу}
# name {Tanchon|단천|단천시}
# isPartOf_label {Baran district|Rajasthan}
# name {Huichon|희천|희천시}
# name {Aonla|Aonla Uttar Pradesh}
# isPartOf_label {Bareilly district|Uttar Pradesh}
# isPartOf_label {Chandauli district|Uttar Pradesh}
# isPartOf_label {New York|Queens}
# name {Islampur|इस्लामपुर}
# isPartOf_label {Manipur|Thoubal district}
# name {Jalalabad|ਜਲਾਲਾਬਾਦ}
# isPartOf_label {Fazilka district|Punjab India}
# name {Jalalabad|Jalalabad Shahjahanpur}
# isPartOf_label {Shahjahanpur district|Uttar Pradesh}
# name {Jalalabad|Jalalabad Muzaffarnagar}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# name {Jalna|Jalna Maharashtra}
# isPartOf_label {Jalna district|Maharashtra}
# name {Chongju|정주|정주시}
# timeZone_label {British Summer Time|Greenwich Mean Time}
# utcOffset {+0|+1}
# governmentType_label {City status in the United Kingdom|Unitary authority}
# isPartOf_label {Hampshire|South East England}
# isPartOf_label {Ganjam district|Odisha}
# utcOffset {-5|-6}
# isPartOf_label {Alabama|Chambers County Alabama}
# elevation {220.066|257.0}
# isPartOf_label {Maharashtra|Thane}
# isPartOf_label {Bihar|Munger district}
# name {Kusong|구성|구성시}
# isPartOf_label {Jammu and Kashmir|Ladakh}
# isPartOf_label {Jammu and Kashmir|Ladakh}
# isPartOf_label {Banka district|Bhagalpur division|Bihar}
# isPartOf_label {Hazaribagh district|Jharkhand}
# utcOffset {-5|-6}
# isPartOf_label {Mississippi|Webster County Mississippi}
# elevation {117.0|117.043}
# areaLand {8.4e+06|8.54696e+06}
# name {City of Leeds|Leeds}
# timeZone_label {British Summer Time|Greenwich Mean Time}
# utcOffset {+0|+1}
# governmentType_label {City status in the United Kingdom|Metropolitan borough}
# isPartOf_label {England|Leeds city centre|West Yorkshire|Yorkshire and the Humber}
# areaCode {0113 (urban core)|01924 (Wakefield nos)|01937 (Wetherby/ Boston Spa)|01943 (Guiseley/ Otley)|01977 (Pontefract nos)}
# elevation {10.0|10.0584}
# populationDensity {1379.93|1380.0}
# isPartOf_label {Kanyakumari district|Tamil Nadu}
# isPartOf_label {Jharkhand|West Singhbhum district}
# name {Piro|पिरो}
# isPartOf_label {Bhojpur district India|Bihar}
# utcOffset {-5|-6}
# isPartOf_label {New York|Queens}
# isPartOf_label {New York|Queens}
# name {Satana|सटाणा}
# isPartOf_label {Maharashtra|Nashik district}
# wgs84_pos#lat {20.5797|20.5936}
# wgs84_pos#long {74.2|74.216}
# name {Yellapur|Yellapura}
# isPartOf_label {Karnataka|Uttara Kannada}
# name {Jogighopa|যোগীঘোপা}
# isPartOf_label {Assam|Bongaigaon district}
# isPartOf_label {Andhra Pradesh|Vizianagaram district}
# name {Tongchuan|铜川|铜川市}
# name {Adelong|Wynyard}
# wgs84_pos#lat {-35.3|35.3}
# isPartOf_label {Andhra Pradesh|Nalgonda district}
# isPartOf_label {Adilabad district|Andhra Pradesh}
# name {Antu|Antu India}
# isPartOf_label {Pratapgarh district Uttar Pradesh|Uttar Pradesh}
# name {Shahpur|शाहपुर}
# isPartOf_label {Bhojpur district India|Bihar}
# wgs84_pos#lat {25.58|25.6}
# wgs84_pos#long {84.4|84.45}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# isPartOf_label {Bokaro district|Jharkhand}
# name {Liupanshui|六盘水|六盘水市}
# wgs84_pos#lat {-41.0667|41.0636}
# wgs84_pos#long {145.875|145.883}
# name {Xingcheng|兴城|兴城市}
# isPartOf_label {Huludao|Liaoning}
# elevation {8.0|8.2296}
# wgs84_pos#lat {40.4975|40.6167}
# wgs84_pos#long {120.733|120.801}
# utcOffset {-5|-6}
# name {Salon|Salon India}
# isPartOf_label {Amethi district|Uttar Pradesh}
# name {Skënderaj|Srbica|Србица}
# utcOffset {+1|+2}
# wgs84_pos#lat {42.7333|42.7467}
# wgs84_pos#long {20.7833|20.7886}
# name {Dragash|Dragaš|Dragaš (Драгаш)|Sharri}
# utcOffset {+1|+2}
# wgs84_pos#lat {42.05|42.0667}
# name {Deori|देवरी}
# isPartOf_label {Gondia district|Maharashtra}
# isPartOf_label {Beed district|Maharashtra}
# isPartOf_label {Guerrero|Huitzuco de los Figueroa}
# name {Shulan|舒兰|舒兰市}
# isPartOf_label {Jilin|Jilin City}
# utcOffset {-4|-5}
# isPartOf_label {Cass County Indiana|Indiana}
# elevation {192.938|193.0}
# populationDensity {811.7|811.741}
# wgs84_pos#lat {40.7535|40.7536}
# wgs84_pos#long {-86.3606|-86.3605}
# areaLand {2.266e+07|2.26624e+07}
# isPartOf_label {Core Neighbourhoods SDA Saskatoon|Saskatoon}
# wgs84_pos#lat {52.1242|52.1248}
# wgs84_pos#long {-106.641|-106.638}
# isPartOf_label {North Region Brazil|Pará}
# wgs84_pos#lat {-2.6374|-2.63583}
# wgs84_pos#long {-54.9369|-54.9361}
# isPartOf_label {Fatehpur district|Uttar Pradesh}
# isPartOf_label {Akola district|Maharashtra}
# isPartOf_label {Andhra Pradesh|Ranga Reddy district}
# isPartOf_label {Amravati district|Maharashtra}
# isPartOf_label {Bhandara district|Maharashtra}
# isPartOf_label {Gondia district|Maharashtra}
# isPartOf_label {Nutana SDA Saskatoon|Saskatoon}
# isPartOf_label {Moerdijk|North Brabant}
# isPartOf_label {Ahmednagar district|Maharashtra}
# wgs84_pos#lat {19.5407|19.5408}
# wgs84_pos#long {74.0061|74.0075}
# isPartOf_label {Maharashtra|Satara district}
# utcOffset {+4|+5}
# isPartOf_label {Assam|Hailakandi district}
# isPartOf_label {Madhya Pradesh|Ujjain district}
# name {Margherita|মাৰ্ঘেৰিটা}
# isPartOf_label {Assam|Tinsukia district}
# isPartOf_label {New York|Queens}
# utcOffset {-5|-6}
# isPartOf_label {Jackson County Wisconsin|Wisconsin}
# elevation {242.0|242.011}
# populationDensity {341.083|341.1}
# areaLand {1.0619e+07|1.062e+07}
# isPartOf_label {Andhra Pradesh|Vizianagaram district}
# isPartOf_label {Bahia|Northeast Region Brazil}
# isPartOf_label {Adilabad district|Andhra Pradesh}
# utcOffset {-5|-6}
# isPartOf_label {Kentucky|Marshall County Kentucky}
# elevation {103.937|104.0}
# populationDensity {75.0969|75.1}
# areaLand {3.6e+07|3.60008e+07}
# isPartOf_label {Odisha|Rayagada district}
# isPartOf_label {Andhra Pradesh|Srikakulam district}
# wgs84_pos#long {83.2333|84.2333}
# name {Wada|वाडा}
# isPartOf_label {Maharashtra|Thane district}
# wgs84_pos#lat {19.39|19.65}
# wgs84_pos#long {73.08|73.13}
# isPartOf_label {Balasore district|Odisha}
# name {Nalconagar|ନାଲକୋନଗର}
# isPartOf_label {Angul district|Odisha}
# wgs84_pos#lat {20.849|20.8493}
# wgs84_pos#long {85.154|85.1542}
# wgs84_pos#lat {-33.751|-33.6833}
# wgs84_pos#long {-53.45|-53.3947}
# name {Ramnagar|Ramnagar Barabanki}
# isPartOf_label {Barabanki district|Uttar Pradesh}
# name {Sumbal|Sumbal Jammu and Kashmir}
# isPartOf_label {Baramulla district|Jammu and Kashmir}
# name {Municipality of Kisela Voda|Општина Кисела Вода}
# name {Municipality of Karpoš|Општина Карпош}
# name {Municipality of Gjorche Petrov|Општина Ѓорче Петров}
# name {Municipality of Butel|Општина Бутел}
# isPartOf_label {Banka district|Bihar}
# name {City of Catbalogan|Siyudad han Catbalogan}
# isPartOf_label {Eastern Visayas|Samar}
# name {Kurdish: Xurmatû|Turkish: Tuz hurma|Tuz Khormato}
# isPartOf_label {Saladin Province|Tooz District}
# wgs84_pos#lat {34.8772|34.8833}
# wgs84_pos#long {44.6333|44.6383}
# isPartOf_label {Colima|Villa de Álvarez Municipality}
# wgs84_pos#lat {19.25|19.2672}
# wgs84_pos#long {-103.738|-103.733}
# isPartOf_label {Baramulla district|Jammu and Kashmir}
# name {Suar|Suar Uttar Pradesh}
# isPartOf_label {Rampur district|Uttar Pradesh}
# isPartOf_label {Chhattisgarh|Sarguja_District}
# isPartOf_label {Chhattisgarh|Durg district}
# isPartOf_label {Maharashtra|Satara district}
# isPartOf_label {Jabalpur district|Madhya Pradesh}
# name {Kota|कोटा}
# isPartOf_label {Bilaspur district Chhattisgarh|Chhattisgarh}
# isPartOf_label {Chhattisgarh|Durg district}
# isPartOf_label {Amsterdam (VOC ship)|North Holland}
# utcOffset {-5|-6}
# isPartOf_label {Iowa|Story County Iowa}
# elevation {287.0|287.122}
# populationDensity {940.39|940.4}
# areaLand {6.27e+07|6.27036e+07}
# name {Acapulco|Acapulco de Juárez}
# utcOffset {−5|−6}
# utcOffset {-7|-8}
# isPartOf_label {Clatsop County Oregon|Oregon}
# elevation {7.0|7.0104}
# populationDensity {594.0|594.018}
# areaLand {1.595e+07|1.59543e+07}
# name {Abadan|آبادان}
# utcOffset {+3:30|+4:30}
# isPartOf_label {Abadan County|Central District (Abadan County)|Khuzestan Province}
# utcOffset {-4|-5}
# isPartOf_label {Calhoun County Michigan|Michigan}
# elevation {289.865|290.0}
# populationDensity {754.3|754.328}
# areaLand {1.142e+07|1.14218e+07}
# name {Alicante|Alicante/Alacant}
# utcOffset {+1|+2}
# isPartOf_label {Alacantí|Province of Alicante|Valencian Community}
# name {Abadeh|آباده}
# utcOffset {+3:30|+4:30}
# isPartOf_label {Abadeh County|Central District (Abadeh County)|Fars Province}
# name {Ajmer|अजमेर}
# isPartOf_label {Ajmer district|Rajasthan}
# utcOffset {-5|-6}
# isPartOf_label {Brown County South Dakota|South Dakota}
# elevation {396.85|397.0}
# populationDensity {649.9|649.926}
# areaLand {4.014e+07|4.01448e+07}
# utcOffset {−7|−8}
# isPartOf_label {Alameda County California|California}
# areaLand {2.7482e+07|2.74824e+07}
# isPartOf_label {Aveiro District|Baixo Vouga Subregion|Centro Region Portugal}
# name {Buffalo New York|City of Buffalo}
# utcOffset {−4|−5}
# isPartOf_label {Erie County New York|New York}
# elevation {182.88|183.0}
# populationDensity {2485.03|2568.8}
# areaLand {1.05154e+08|1.052e+08}
# utcOffset {-4|-5}
# isPartOf_label {Massachusetts|Middlesex County Massachusetts}
# elevation {12.0|12.192}
# populationDensity {6340.6|6341.98}
# areaLand {1.665e+07|1.66536e+07}
# name {City of Columbus|Columbus Ohio}
# utcOffset {-4|-5}
# isPartOf_label {Delaware County Ohio|Fairfield County Ohio|Franklin County Ohio|Ohio}
# elevation {274.93|275.0}
# populationDensity {1399.2|1399.23}
# areaLand {5.62468e+08|5.6247e+08}
# name {City of Cleveland|Cleveland}
# utcOffset {-4|-5}
# isPartOf_label {Cuyahoga County Ohio|Ohio}
# elevation {199.0|199.034}
# populationDensity {1971.8|1971.82}
# areaLand {2.0124e+08|2.01242e+08}
# name {Cologne|Köln}
# utcOffset {−6|−7}
# isPartOf_label {Colorado|El Paso County Colorado}
# populationDensity {865.57|865.834}
# areaLand {4.811e+08|5.02717e+08}
# name {Autonomous City of Ceuta|Ceuta}
# utcOffset {+1|+2}
# timeZone_label {British Summer Time|Greenwich Mean Time}
# utcOffset {+1|0}
# isPartOf_label {Ceremonial counties of England|City status in the United Kingdom|England|Greater London|Guildhall London|Sui generis}
# utcOffset {−05:00|−06:00}
# isPartOf_label {Cook County Illinois|DuPage County Illinois|Illinois}
# populationDensity {4447.4|4580.87}
# name {Carson City Nevada|Consolidated Municipality of Carson City}
# utcOffset {−7|−8}
# elevation {1463.0|1463.65}
# areaLand {4.03e+08|4.04038e+08}
# utcOffset {-4|-5}
# isPartOf_label {Montgomery County Ohio|Ohio}
# elevation {224.942|225.0}
# populationDensity {981.9|981.935}
# areaLand {1.4413e+08|1.44133e+08}
# name {City of Dar es Salaam|Dar es Salaam}
# name {City and County of Denver|Denver}
# utcOffset {−6|−7}
# elevation {1563.62|1564.0}
# populationDensity {1561.0|1561.4}
# areaLand {3.97045e+08|3.972e+08}
# utcOffset {-5|-6}
# isPartOf_label {Iowa|Scott County Iowa}
# populationDensity {611.4|611.431}
# name {City of Detroit|Detroit}
# utcOffset {−4|−5}
# isPartOf_label {Michigan|Wayne County Michigan}
# areaLand {3.5936e+08|3.59361e+08}
# utcOffset {+1|+2}
# name {(also colloq. Embra and Edinburrie)|City of Edinburgh|Scots: Edinburgh|Scottish Gaelic: Dùn Èideann}
# timeZone_label {British Summer Time|Greenwich Mean Time}
# utcOffset {+0|+1}
# homepage {http://www.edinburgh-inspiringcapital.com/|http://www.edinburgh.gov.uk/}
# governmentType_label {City status in the United Kingdom|Subdivisions of Scotland}
# utcOffset {-7|-8}
# isPartOf_label {Lane County Oregon|Oregon}
# elevation {131.064|131.1}
# populationDensity {1379.3|1379.31}
# areaLand {1.1323e+08|1.13234e+08}
# name {Edo|江戸}
# name {Gernika|Gernika-Lumo}
# utcOffset {+1|+2}
# isPartOf_label {Basque Country (autonomous community)|Biscay|Busturialdea}
# utcOffset {–5|–6}
# isPartOf_label {Calumet Township Lake County Indiana|Hobart Township Lake County Indiana|Indiana|Lake County Indiana}
# populationDensity {621.663|621.7}
# areaLand {1.2916e+08|1.29163e+08}
# name {City of Houston|Houston}
# utcOffset {-5|-6}
# isPartOf_label {Fort Bend County Texas|Harris County Texas|Montgomery County Texas|Texas}
# elevation {13.0|13.1064}
# populationDensity {1398.85|1505.0}
# areaLand {1.5529e+09|1.55293e+09}
# name {Herāt|هرات}
# name {Hannover|Hanover}
# name {City of Hamilton|Hamilton}
# utcOffset {−4|−5}
# utcOffset {+1|+2}
# isPartOf_label {Hedmark|ISO 3166-2:NO}
# utcOffset {−4|−5}
# isPartOf_label {New York|Tompkins County New York}
# areaLand {1.41e+07|1.42449e+07}
# name {(Yerushalayim)|(al-Quds)|Jerusalem}
# timeZone_label {Israel Standard Time|Israel Summer Time}
# utcOffset {+2|+3}
# name {City of Jackson|Jackson Mississippi}
# utcOffset {-5|-6}
# isPartOf_label {Hinds County Mississippi|Madison County Mississippi|Mississippi|Rankin County Mississippi}
# elevation {85.0|85.0392}
# areaLand {2.7169e+08|2.717e+08}
# name {Kabul|کا‌‌‌بل}
# name {Kagoshima|鹿児島|鹿児島市 · Kagoshima City}
# isPartOf_label {Kagoshima Prefecture|Kyushu}
# name {Kathmandu|येँ देय्‌}
# isPartOf_label {Bagmati Zone|Kathmandu District}
# name {Kandahar|کندهار}
# name {City of Lansing|Lansing Michigan}
# utcOffset {-4|-5}
# isPartOf_label {Eaton County Michigan|Ingham County Michigan|Michigan}
# elevation {262.0|262.128}
# populationDensity {1224.1|1224.14}
# areaLand {9.33691e+07|9.337e+07}
# areaMetro {4.44079e+09|4.4408e+09}
# areaUrban {3.544e+08|4.09736e+08}
# name {City of Mexico|Ciudad de México|Mexico City}
# utcOffset {−5|−6}
# isPartOf_label {Maharashtra|Mumbai City district|Mumbai Suburban district}
# areaMetro {4.355e+09|4.35507e+09}
# utcOffset {−3|−4}
# isPartOf_label {Moncton Parish New Brunswick|New Brunswick|Westmorland County New Brunswick}
# populationDensity {473.1|476.257}
# areaMetro {2.406e+09|2.4061e+09}
# areaUrban {1.45039e+08|1.46e+08}
# name {(Spanish)|Autonomous City of Melilla|Melilla}
# utcOffset {-4|-5}
# isPartOf_label {Marquette County Michigan|Michigan}
# elevation {202.997|203.0}
# populationDensity {723.9|723.903}
# name {Mazar-e Sharīf|مزارِ شریف}
# utcOffset {+01|+02}
# utcOffset {-5|-6}
# isPartOf_label {Alabama|Mobile County Alabama}
# elevation {3.0|3.048}
# name {Nagasaki|長崎|長崎市 · Nagasaki City}
# isPartOf_label {Kyushu|Nagasaki Prefecture}
# populationDensity {1228.96|1230.0}
# name {Metropolitan Government of|Nashville and Davidson County|Nashville Tennessee}
# utcOffset {-5|-6}
# isPartOf_label {Davidson County Tennessee|Tennessee}
# name {City of Plymouth|Plymouth}
# timeZone_label {British Summer Time|Greenwich Mean Time}
# utcOffset {+1|0}
# isPartOf_label {Devon|South West England}
# populationDensity {3188.0|3189.59}
# name {City of Portland|Portland Oregon}
# utcOffset {-7|-8}
# isPartOf_label {Clackamas County Oregon|Multnomah County Oregon|Oregon|Washington County Oregon}
# elevation {-0.36576|0.3048|15.24|37.4152|37.4181|390.144|2226.87}
# populationDensity {1689.2|1689.24}
# areaLand {3.4558e+08|3.45582e+08}
# name {Prague|Praha}
# utcOffset {+1|+2}
# name {Riga|Rīga}
# utcOffset {+2|+3}
# utcOffset {+1|+2}
# timeZone_label {Daylight saving time|Mountain Time Zone}
# utcOffset {&minus;6|&minus;7}
# isPartOf_label {Chaves County New Mexico|New Mexico}
# elevation {1089.0|1089.05}
# areaLand {7.48507e+07|7.5e+07}
# utcOffset {−7|−8}
# isPartOf_label {Nevada|Washoe County Nevada}
# elevation {1373.0|1373.12}
# name {City of St. Louis|St. Louis}
# utcOffset {−5|−6}
# isPartOf_label {Greater St. Louis|Independent city (United States)|Missouri}
# elevation {142.0|142.037}
# populationDensity {1983.6|1984.6}
# areaLand {1.6032e+08|1.604e+08}
# name {City of Santa Monica|Santa Monica California}
# utcOffset {-7|-8}
# isPartOf_label {California|Los Angeles County California}
# name {City of San Diego|San Diego California}
# utcOffset {-7|-8}
# isPartOf_label {California|San Diego County California}
# elevation {21.9456|22.0}
# name {City of Skopje|Skopje|Град Скопје|Скопје}
# utcOffset {+1|+2}
# utcOffset {+1|+2}
# isPartOf_label {South Governorate|Tyre District}
# isPartOf_label {Castile-La Mancha|Province of Toledo}
# utcOffset {+2|+3}
# elevation {57.2|57.3024}
# maximumElevation {78.9432|79.0}
# populationDensity {2678.0|2679.0}
# areaLand {3.78138e+07|3.79e+07}
# name {City of Windsor|Windsor}
# timeZone_label {Daylight saving time in Canada|Eastern Time Zone}
# utcOffset {−4|−5}
# utcOffset {&minus;5|&minus;6}
# isPartOf_label {Black Hawk County Iowa|Iowa}
# populationDensity {430.2|430.234}
# areaLand {1.58999e+08|1.59e+08}
# utcOffset {-4|-5}
# isPartOf_label {Macomb County Michigan|Michigan}
# elevation {191.0|191.11}
# populationDensity {1505.49|1505.5}
# areaLand {8.904e+07|8.90438e+07}
# utcOffset {+1|+2}
# utcOffset {-7|-8}
# isPartOf_label {Idaho|Nez Perce County Idaho}
# populationDensity {714.7|714.714}
# areaLand {4.46255e+07|4.463e+07}
# name {Boise Idaho|City of Boise}
# utcOffset {-6|-7}
# isPartOf_label {Ada County Idaho|Idaho}
# elevation {832.104|850.0}
# populationDensity {1000.6|1000.62}
# areaLand {2.0554e+08|2.05541e+08}
# name {Kingston and St. Andrew Corporation / Greater Kingston|Kingston}
# isPartOf_label {Kingston Parish|Saint Andrew Parish Jamaica|Surrey County Jamaica}
# elevation {9.0|9.144}
# isPartOf_label {Hassan district|Karnataka}
# name {Kyoto|· Kyoto City|京都}
# isPartOf_label {Kansai region|Kyoto Prefecture}
# utcOffset {+1|+2}
# isPartOf_label {Andalusia|Province of Granada|Vega de Granada}
# timeZone_label {Daylight saving time in Uruguay|UTC−03:00}
# utcOffset {−2|−3}
# name {Poltava|Полтава}
# utcOffset {+2|+3}
# name {City of London|London}
# utcOffset {−4|−5}
# utcOffset {−7|−8}
# isPartOf_label {California|Monterey County California}
# elevation {7.9248|8.0}
# areaLand {2.19268e+07|2.1927e+07}
# name {75px|City of Saint Paul|Saint Paul Minnesota}
# utcOffset {-5|-6}
# isPartOf_label {Minnesota|Ramsey County Minnesota}
# elevation {213.97|214.0}
# populationDensity {2117.46|2117.5}
# areaLand {1.34628e+08|1.3463e+08}
# name {Thessaloniki|Θεσσαλονίκη}
# utcOffset {+2|+3}
# isPartOf_label {Central Macedonia|Thessaloniki (regional unit)}
# isPartOf_label {Faizabad district|Uttar Pradesh}
# utcOffset {−7|−8}
# isPartOf_label {Oregon|Washington County Oregon}
# elevation {57.6072|57.61}
# populationDensity {1851.2|1851.21}
# areaLand {4.851e+07|4.85105e+07}
# utcOffset {+1|+2}
# elevation {295.0|295.046}
# name {Walvis Bay|Walvisbaai}
# utcOffset {+1|+2}
# name {City of Rockville|Rockville Maryland}
# utcOffset {-4|-5}
# isPartOf_label {Maryland|Montgomery County Maryland}
# elevation {137.0|137.465}
# populationDensity {1749.27|1749.3}
# areaLand {3.499e+07|3.49907e+07}
# utcOffset {-4|-5}
# isPartOf_label {Cumberland County Maine|Maine}
# elevation {18.8976|19.0}
# populationDensity {1199.3|1199.31}
# areaLand {5.519e+07|5.51926e+07}
# isPartOf_label {Castile and León|Province of Burgos}
# utcOffset {-4|-5}
# isPartOf_label {Florida|Palm Beach County Florida}
# populationDensity {1035.83|1061.7}
# areaLand {7.04e+07|7.04477e+07}
# name {Queens|Queens County}
# isPartOf_label {New York|New York City}
# name {Leeuwarden|Ljouwert}
# utcOffset {+1|+2}
# name {Kerch|Керч|Керчь}
# utcOffset {+2|+3}
# name {City of Las Vegas|Las Vegas}
# utcOffset {−7|−8}
# isPartOf_label {Clark County Nevada|Nevada}
# elevation {609.905|610.0}
# isPartOf_label {Kolkata district|Presidency division|West Bengal}
# elevation {9.0|9.144}
# areaMetro {1.88667e+09|1.88668e+09}
# name {Bhopal|भोपाल}
# isPartOf_label {Bhopal district|Madhya Pradesh}
# name {Pyongyang|Pyongyang Directly Governed City|평양}
# utcOffset {-7|-8}
# isPartOf_label {Oregon|Washington County Oregon}
# elevation {91.0|91.44}
# populationDensity {1570.39|1570.4}
# areaLand {3.05878e+07|3.059e+07}
# utcOffset {-7|-8}
# isPartOf_label {Benton County Oregon|Oregon}
# elevation {68.28|71.628}
# populationDensity {1488.19|1488.2}
# areaLand {3.65965e+07|3.66e+07}
# name {Havana|La Habana}
# timeZone_label {UTC−04:00|UTC−05:00}
# utcOffset {-4|-5}
# elevation {59.0|59.1312}
# name {City and County of San Francisco|San Francisco}
# utcOffset {-7|-8}
# name {City of Takoma Park|Takoma Park Maryland}
# utcOffset {-4|-5}
# ...
# isPartOf_label {Bihar|Buxar district}
# isPartOf_label {Salem district|Tamil Nadu}
# isPartOf_label {Madurai district|Tamil Nadu}
# name {Ellenabad|ऐलनाबाद}
# isPartOf_label {Haryana|Sirsa district}
# isPartOf_label {Jalgaon district|Maharashtra}
# isPartOf_label {Ghaziabad district India|Uttar Pradesh}
# name {Farrukhnagar|फ़रुख़नगर}
# isPartOf_label {Gurgaon district|Haryana}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# wgs84_pos#lat {29.0237|29.0437}
# wgs84_pos#long {79.1447|79.2465}
# isPartOf_label {Madhya Pradesh|Narsinghpur district}
# name {Gadhada|ગઢડા}
# isPartOf_label {Bhavnagar district|Gujarat}
# isPartOf_label {Himachal Pradesh|Una district}
# name {Gadhinglaj|गडहिंग्लज}
# isPartOf_label {Kolhapur district|Maharashtra}
# isPartOf_label {Tripura|West Tripura district}
# isPartOf_label {Amroha district|Uttar Pradesh}
# wgs84_pos#lat {28.8347|28.85}
# wgs84_pos#long {78.23|78.2439}
# isPartOf_label {Ganderbal district|Jammu and Kashmir}
# isPartOf_label {Chhattisgarh|Rajnandgaon district}
# isPartOf_label {Aurangabad district Maharashtra|Maharashtra}
# wgs84_pos#lat {19.699|19.6991}
# wgs84_pos#long {75.0|75.0086}
# isPartOf_label {Salem district|Tamil Nadu}
# isPartOf_label {Saharanpur district|Uttar Pradesh}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Sagar district}
# isPartOf_label {Bhavnagar district|Gujarat}
# name {Gauripur|গৌৰীপুৰ}
# isPartOf_label {Assam|Dhubri district}
# name {Gowribidanur|ಗೌರಿಬಿದನೂರು}
# isPartOf_label {Chikkaballapur district|Karnataka}
# wgs84_pos#lat {13.59|13.61}
# isPartOf_label {Budaun district|Uttar Pradesh}
# isPartOf_label {Chhattisgarh|Dantewada district}
# isPartOf_label {Madhya Pradesh|Seoni district}
# isPartOf_label {Patiala district|Punjab India}
# isPartOf_label {Haryana|Karnal district}
# isPartOf_label {Chhattisgarh|Raigarh district}
# isPartOf_label {East Singhbhum district|Jharkhand}
# wgs84_pos#lat {22.36|22.6}
# wgs84_pos#long {86.29|86.48}
# isPartOf_label {Jammu and Kashmir|Jammu district}
# name {Kafarakab|كفرعقاب}
# utcOffset {+2|+3}
# isPartOf_label {Matn District|Mount Lebanon Governorate}
# isPartOf_label {Uttarakhand|Uttarkashi district}
# isPartOf_label {Maharajganj district|Uttar Pradesh}
# isPartOf_label {Lakhimpur Kheri District|Uttar Pradesh}
# isPartOf_label {Erongo Region|Karibib Constituency}
# name {Kadiri|కదిరి}
# isPartOf_label {Anantapur district|Andhra Pradesh}
# name {Sariwon|사리원|사리원시}
# wgs84_pos#lat {38.5064|38.5078}
# wgs84_pos#long {125.754|125.76}
# isPartOf_label {Sonbhadra district|Uttar Pradesh}
# isPartOf_label {Mau district|Uttar Pradesh}
# name {Ghugus|घुगुस}
# isPartOf_label {Chandrapur district|Maharashtra}
# name {Gobindpur|गोविन्दपुर}
# isPartOf_label {Dhanbad district|Jharkhand}
# wgs84_pos#lat {22.63|23.83}
# wgs84_pos#long {86.07|86.52}
# isPartOf_label {Chamoli district|Uttarakhand}
# isPartOf_label {Madhya Pradesh|Ujjain district}
# name {Gohana|गोहाना}
# isPartOf_label {Haryana|Sonipat district}
# isPartOf_label {Hamirpur district Uttar Pradesh|Uttar Pradesh}
# name {Gohpur|গহপুৰ}
# isPartOf_label {Assam|Sonitpur district}
# isPartOf_label {Hardoi district|Uttar Pradesh}
# isPartOf_label {Bhind district|Madhya Pradesh}
# isPartOf_label {Assam|Kokrajhar district}
# name {Gosainganj|Gosainganj Lucknow}
# isPartOf_label {Lucknow district|Uttar Pradesh}
# isPartOf_label {Jhunjhunu district|Rajasthan}
# isPartOf_label {Alwar district|Rajasthan}
# wgs84_pos#lat {26.45|27.3}
# wgs84_pos#long {74.38|77.0}
# isPartOf_label {Karnataka|Kolar district}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Bhilwara district|Rajasthan}
# isPartOf_label {Bulandshahr district|Uttar Pradesh}
# name {Gundlupet|Gundlupet ಗುಂಡ್ಲುಪೇಟೆ}
# isPartOf_label {Chamarajanagar district|Karnataka}
# isPartOf_label {Budaun district|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Rewa District}
# name {Guriahati|গুড়িয়াহাটি}
# isPartOf_label {Cooch Behar district|West Bengal}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# isPartOf_label {Kannauj district|Uttar Pradesh}
# isPartOf_label {Baramulla district|Jammu and Kashmir}
# isPartOf_label {Bijnor district|Uttar Pradesh}
# isPartOf_label {Karnataka|Uttara Kannada}
# isPartOf_label {Gujarat|Surendranagar district}
# isPartOf_label {Aligarh district|Uttar Pradesh}
# isPartOf_label {Gujarat|Patan district}
# isPartOf_label {Davanagere district|Karnataka}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Khandwa district|Madhya Pradesh}
# isPartOf_label {Indore district|Madhya Pradesh}
# isPartOf_label {Dehradun district|Uttarakhand}
# isPartOf_label {Giridih district|Jharkhand}
# isPartOf_label {Damoh district|Madhya Pradesh}
# isPartOf_label {Balaghat district|Madhya Pradesh}
# isPartOf_label {Jammu and Kashmir|Kathua district}
# name {Hirekerur|ಹಿರೇಕೇರೂರು}
# isPartOf_label {Haveri|Haveri district|Karnataka}
# isPartOf_label {Davanagere district|Karnataka}
# name {Hosanagara|ಹೊಸನಗರ}
# isPartOf_label {Karnataka|Shimoga district}
# isPartOf_label {Assam|Barpeta district}
# name {Hukkeri|ಹುಕ್ಕೇರಿ  Hukkeri}
# isPartOf_label {Belgaum district|Karnataka}
# name {Hunasuru|Hunsur}
# isPartOf_label {Karnataka|Mysore district}
# isPartOf_label {Andhra Pradesh|Srikakulam district}
# name {Ichalkaranji|इचलकरंजी}
# isPartOf_label {Kolhapur district|Maharashtra}
# isPartOf_label {Madhya Pradesh|Sehore district}
# isPartOf_label {Aligarh district|Uttar Pradesh}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# name {Ilkal ಇಳಕಲ್|Kandagal}
# isPartOf_label {Bagalkot district|Karnataka}
# isPartOf_label {Pudukkottai district|Tamil Nadu}
# name {Arvind|Itaunja}
# isPartOf_label {Lucknow district|Uttar Pradesh}
# isPartOf_label {Davanagere district|Karnataka}
# isPartOf_label {Bulandshahr district|Uttar Pradesh}
# isPartOf_label {Bhilwara district|Rajasthan}
# isPartOf_label {Madhya Pradesh|Shahdol district}
# isPartOf_label {Pali district|Rajasthan}
# isPartOf_label {Anuppur district|Madhya Pradesh}
# name {Jalali|Jalali India}
# isPartOf_label {Aligarh district|Uttar Pradesh}
# isPartOf_label {Etaeh_district|Uttar Pradesh}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Chhindwara district|Madhya Pradesh}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# isPartOf_label {Bahraich district|Uttar Pradesh}
# name {Jasdan|જસદણ}
# isPartOf_label {Gujarat|Rajkot district}
# isPartOf_label {Deoghar district|Jharkhand}
# isPartOf_label {Firozabad district|Uttar Pradesh}
# isPartOf_label {Madhya Pradesh|Tikamgarh district}
# name {Jawad|जावद}
# isPartOf_label {Madhya Pradesh|Neemuch district}
# isPartOf_label {Himachal Pradesh|Kangra district}
# isPartOf_label {Madhya Pradesh|Sehore district}
# name {Jejuri|जेजुरी}
# isPartOf_label {Maharashtra|Pune district}
# name {Jevargi|Jevargi / ಜೇವರ್ಗಿ}
# isPartOf_label {Gulbarga district|Karnataka}
# name {Jhalda|ঝালদা}
# isPartOf_label {Purulia district|West Bengal}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# isPartOf_label {Maharashtra|Parbhani district}
# name {Jiran|जीरन}
# isPartOf_label {Madhya Pradesh|Neemuch district}
# isPartOf_label {Imphal East district|Manipur}
# isPartOf_label {Azamgarh district|Uttar Pradesh}
# isPartOf_label {Jaipur district|Rajasthan}
# isPartOf_label {Tripura|West Tripura district}
# name {Jourian|Lal}
# isPartOf_label {Jammu and Kashmir|Jammu district}
# isPartOf_label {Himachal Pradesh|Shimla district}
# isPartOf_label {Mahoba district|Uttar Pradesh}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# isPartOf_label {Sultanpur district|Uttar Pradesh}
# isPartOf_label {Adilabad district|Andhra Pradesh}
# isPartOf_label {Madhya Pradesh|Morena district}
# isPartOf_label {Shamli district|Uttar Pradesh}
# isPartOf_label {Budaun district|Uttar Pradesh}
# name {Kalamnuri|कळमनुरी}
# isPartOf_label {Hingoli district|Maharashtra}
# isPartOf_label {Gujarat|Jamnagar district}
# isPartOf_label {East Singhbhum district|Jharkhand}
# isPartOf_label {Pilibhit district|Uttar Pradesh}
# isPartOf_label {Kannur district|Kerala}
# wgs84_pos#lat {11.95|12.0}
# wgs84_pos#long {75.29|75.35}
# isPartOf_label {Gujarat|Panchmahal district}
# isPartOf_label {Farrukhabad district|Uttar Pradesh}
# name {Kamalpur|Kamalpur India}
# isPartOf_label {Dhalai district|Tripura}
# isPartOf_label {Bharatpur district|Rajasthan}
# name {Kampli|ಕಂಪ್ಲಿ}
# isPartOf_label {Bellary district|Karnataka}
# wgs84_pos#lat {15.24|15.4}
# wgs84_pos#long {76.37|76.62}
# name {Kanchrapara|কাচঁরাপাড়া}
# isPartOf_label {North 24 Parganas district|West Bengal}
# wgs84_pos#lat {22.56|22.97}
# wgs84_pos#long {88.26|88.43}
# isPartOf_label {Muzaffarnagar district|Uttar Pradesh}
# isPartOf_label {Andhra Pradesh|Prakasam district}
# wgs84_pos#lat {15.2167|17.07}
# wgs84_pos#long {78.49|79.9167}
# isPartOf_label {Jharkhand|Seraikela Kharsawan district}
# isPartOf_label {Chhattisgarh|Kanker district}
# isPartOf_label {Rajasthan|Udaipur district}
# isPartOf_label {Balangir district|Odisha}
# isPartOf_label {Moradabad district|Uttar Pradesh}
# wgs84_pos#lat {29.059|29.07}
# wgs84_pos#long {78.628|78.63}
# name {(Shahjahanpur)|Kant|Kant (Shahjahanpur)}
# isPartOf_label {Shahjahanpur district|Uttar Pradesh}
# isPartOf_label {Nayagarh district|Odisha}
# isPartOf_label {Gujarat|Kheda district}
# name {Karambakkudi|கறம்பக்குடி}
# isPartOf_label {Pudukkottai district|Tamil Nadu}
# name {Karanja Lad|कारंजा लाड}
# isPartOf_label {Maharashtra|Washim district}
# wgs84_pos#lat {20.4833|20.8092}
# wgs84_pos#long {77.4833|77.8092}
# isPartOf_label {Mayurbhanj district|Odisha}
# wgs84_pos#lat {21.47|21.78}
# wgs84_pos#long {85.58|85.97}
# name {Karanpur|Sri Karanpur}
# isPartOf_label {Rajasthan|Sri Ganganagar district}
# wgs84_pos#lat {29.5|29.84}
# wgs84_pos#long {73.27|73.5}
# isPartOf_label {Madhya Pradesh|Narsinghpur district}
# isPartOf_label {Madhya Pradesh|Shivpuri district}
# isPartOf_label {Maharashtra|Solapur district}
# name {Karnaprayag|कर्ण प्रयाग}
# isPartOf_label {Chamoli district|Uttarakhand}
# isPartOf_label {Madhya Pradesh|Sagar district}
# isPartOf_label {Pauri Garhwal district|Uttarakhand}
# name {Kasrawad|कसरावद}
# isPartOf_label {Khargone district|Madhya Pradesh}
# isPartOf_label {Balaghat district|Madhya Pradesh}
# isPartOf_label {Chhattisgarh|Korba district}
# name {Katra|Katra Gonda}
# isPartOf_label {Gonda district|Uttar Pradesh}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Krishnagiri district|Tamil Nadu}
# isPartOf_label {Chhattisgarh|Kabirdham district}
# isPartOf_label {Ajmer district|Rajasthan}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# isPartOf_label {Krishnagiri district|Tamil Nadu}
# isPartOf_label {Dhanbad district|Jharkhand}
# isPartOf_label {Kalahandi district|Odisha}
# isPartOf_label {Madhya Pradesh|Ujjain district}
# isPartOf_label {Fatehpur district|Uttar Pradesh}
# name {Khagaul|खगौल}
# isPartOf_label {Bihar|Patna district}
# name {Khagrabari|খাগড়াবাড়ি}
# isPartOf_label {Cooch Behar district|West Bengal}
# isPartOf_label {Jhansi district|Uttar Pradesh}
# isPartOf_label {Sitapur district|Uttar Pradesh}
# isPartOf_label {Ganjam district|Odisha}
# isPartOf_label {Fatehgarh Sahib district|Punjab India}
# isPartOf_label {Chhattisgarh|Durg district}
# isPartOf_label {Rajasthan|Sikar district}
# isPartOf_label {Nayagarh district|Odisha}
# isPartOf_label {Maharashtra|Nagpur district}
# name {Kharar|ਖਰੜ}
# isPartOf_label {Mohali district|Punjab India}
# isPartOf_label {Madhya Pradesh|Tikamgarh district}
# isPartOf_label {Gonda district|Uttar Pradesh}
# isPartOf_label {Cooch Behar district|West Bengal}
# isPartOf_label {Chhattisgarh|Janjgir–Champa district}
# isPartOf_label {Champhai district|Mizoram}
# name {Khatima|खटीमा}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# isPartOf_label {Gujarat|Mehsana district}
# isPartOf_label {Shahjahanpur district|Uttar Pradesh}
# isPartOf_label {Jammu and Kashmir|Pulwama district}
# isPartOf_label {Shahjahanpur district|Uttar Pradesh}
# isPartOf_label {Udham Singh Nagar district|Uttarakhand}
# isPartOf_label {Maharashtra|Nanded district}
# isPartOf_label {Agra district|Uttar Pradesh}
# isPartOf_label {Alwar district|Rajasthan}
# isPartOf_label {Tehri Garhwal district|Uttarakhand}
# isPartOf_label {Mainpuri district|Uttar Pradesh}
# isPartOf_label {Ganjam district|Odisha}
# isPartOf_label {Bangalore district|Karnataka}
# isPartOf_label {Kolhapur district|Maharashtra}
# name {Koilwar|कोइलवार}
# isPartOf_label {Bhojpur district India|Bihar}
# name {Colachel|Kolachal}
# isPartOf_label {Kanyakumari district|Tamil Nadu}
# wgs84_pos#lat {8.15|8.17}
# wgs84_pos#long {77.14|77.24}
# isPartOf_label {Madhya Pradesh|Shivpuri district}
# isPartOf_label {Salem district|Tamil Nadu}
# name {Konnagar|কোন্নগর}
# isPartOf_label {Hooghly district|West Bengal}
# isPartOf_label {Gadag district|Karnataka}
# isPartOf_label {Mau district|Uttar Pradesh}
# isPartOf_label {Andhra Pradesh|Karimnagar district}
# isPartOf_label {Karnataka|Tumkur district}
# isPartOf_label {Anuppur district|Madhya Pradesh}
# isPartOf_label {Sivaganga district|Tamil Nadu}
# isPartOf_label {Karnataka|Mandya district}
# name {Krishnarajpet|ಕೃಷ್ಣರಾಜಪೇಟೆ}
# isPartOf_label {Karnataka|Mandya district}
# isPartOf_label {Bellary district|Karnataka}
# {<class 'NoneType'>, <class 'list'>, <class 'float'>}
# defaultdict(<class 'set'>,
#             {  'areaCode': {  <class 'float'>,
#                               <class 'list'>,
#                               <class 'int'>,
#                               <class 'NoneType'>,
#                               <class 'str'>},
#                'areaLand': {  <class 'float'>,
#                               <class 'list'>,
#                               <class 'NoneType'>},
#                'areaMetro': {  <class 'float'>,
#                                <class 'list'>,
#                                <class 'NoneType'>},
#                'areaUrban': {  <class 'float'>,
#                                <class 'list'>,
#                                <class 'NoneType'>},
#                'elevation': {  <class 'float'>,
#                                <class 'list'>,
#                                <class 'NoneType'>},
#                'governmentType_label': {  <class 'list'>,
#                                           <class 'NoneType'>,
#                                           <class 'str'>},
#                'homepage': {<class 'NoneType'>, <class 'str'>, <class 'list'>},
#                'isPartOf_label': {  <class 'list'>,
#                                     <class 'NoneType'>,
#                                     <class 'str'>},
#                'maximumElevation': {  <class 'float'>,
#                                       <class 'list'>,
#                                       <class 'NoneType'>},
#                'minimumElevation': {<class 'NoneType'>, <class 'float'>},
#                'name': {<class 'NoneType'>, <class 'str'>, <class 'list'>},
#                'populationDensity': {  <class 'float'>,
#                                        <class 'list'>,
#                                        <class 'NoneType'>},
#                'populationTotal': {  <class 'float'>,
#                                      <class 'list'>,
#                                      <class 'int'>,
#                                      <class 'NoneType'>},
#                'timeZone_label': {  <class 'list'>,
#                                     <class 'NoneType'>,
#                                     <class 'str'>},
#                'utcOffset': {  <class 'float'>,
#                                <class 'list'>,
#                                <class 'int'>,
#                                <class 'NoneType'>,
#                                <class 'str'>},
#                'wgs84_pos#lat': {  <class 'float'>,
#                                    <class 'list'>,
#                                    <class 'NoneType'>},
#                'wgs84_pos#long': {  <class 'float'>,
#                                     <class 'list'>,
#                                     <class 'NoneType'>}})
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-242-7b6038f349a7> in <module>()
#       8
#       9 if __name__ == "__main__":
# ---> 10     test()
#
# <ipython-input-242-7b6038f349a7> in test()
#       5
#       6     assert fieldtypes["areaLand"] == set([type(1.1), type([]), type(None)])
# ----> 7     assert fieldtypes['areaMetro'] == set([type(1.1), type(None)])
#       8
#       9 if __name__ == "__main__":
#
# AssertionError:

# %%
s = '55166700'
st = "5e+2"
# Out:
# str

# %%
numbers = sum(c.isdigit() for c in st)
numbers
# Out:
# 2

# %%
s = 'some string'

numbers = sum(c.isdigit() for c in s)
words   = sum(c.isalpha() for c in s)
spaces  = sum(c.isspace() for c in s)
others  = len(s) - numbers - words - spaces

# %%
numbers
# Out:
# 0

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up.

Since in the previous quiz you made a decision on which value to keep for the
"areaLand" field, you now know what has to be done.

Finish the function fix_area(). It will receive a string as an input, and it
has to return a float representing the value of the area or None.
You have to change the function fix_area. You can use extra functions if you
like, but changes to process_file will not be taken into account.
The rest of the code is just an example on how this function can be used.
"""
import codecs
import csv
import json
import pprint
import copy 

CITIES = 'cities.csv'


def fix_area(area):
    
    # YOUR CODE HERE
    fixedArea = ""
 
    if (area == "NULL") is True:

        fixedArea = None
        
    elif area.startswith("{") is True:
            
            char = "{}'" 
            for c in char:
                area = area.replace(c, "")
            
            splitted_area = area.split("|")
            
            most_digits = 0
            
            for mod_area in splitted_area:
                
                num_digits = -1  # Substract the exponent character                   
                sign_digits = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
                
                # Count how many significant digits contains a string
                for ch in mod_area:
                    if (ch in sign_digits) is True:
                        num_digits += 1

                # Set fixedArea to the string with the most significant digits 
                if (num_digits > most_digits):
                    most_digits = num_digits
                    fixedArea = float(mod_area)
                    
    else:
        fixedArea = float(area)
       
    return fixedArea


def process_file(filename):
    # CHANGES TO THIS FUNCTION WILL BE IGNORED WHEN YOU SUBMIT THE EXERCISE
    data = []

    with open(filename, "r") as f:
        reader = csv.DictReader(f)

        #skipping the extra metadata
        for i in range(3):
            l = next(reader)

        # processing file
        for line in reader:
            # calling your function to fix the area value
            if "areaLand" in line:
                line["areaLand"] = fix_area(line["areaLand"])
            data.append(line)

    return data


def test():
    data = process_file(CITIES)
    print("Printing three example results:")
    for n in range(5,8):
        pprint.pprint(data[n]["areaLand"])

    assert data[3]["areaLand"] == None        
    assert data[8]["areaLand"] == 55166700.0
    assert data[20]["areaLand"] == 14581600.0
    assert data[33]["areaLand"] == 20564500.0    


if __name__ == "__main__":
    test()
# Out:
# Printing three example results:
# None
# None
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-294-6e08708b26ae> in <module>()
#      97
#      98 if __name__ == "__main__":
# ---> 99     test()
#
# <ipython-input-294-6e08708b26ae> in test()
#      91
#      92     assert data[3]["areaLand"] == None
# ---> 93     assert data[8]["areaLand"] == 55166700.0
#      94     assert data[20]["areaLand"] == 14581600.0
#      95     assert data[33]["areaLand"] == 20564500.0
#
# AssertionError:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up.

In the previous quiz you recognized that the "name" value can be an array (or
list in Python terms). It would make it easier to process and query the data
later if all values for the name are in a Python list, instead of being
just a string separated with special characters, like now.

Finish the function fix_name(). It will receive a string as an input, and it
will return a list of all the names. If there is only one name, the list will
have only one item in it; if the name is "NULL", the list should be empty.
The rest of the code is just an example on how this function can be used.
"""
import codecs
import csv
import pprint

CITIES = 'cities.csv'


def fix_name(name):
    # YOUR CODE HERE
    fixed_name = []
    
    if (name == "NULL") is True:
        pass
    
    else:
        signs = "{}"
        for s in signs:
            name = name.replace(s, "")
            
        name = name.split("|")  
        
        for n in name:
            fixed_name.append(n)
            
    return fixed_name


def process_file(filename):
    data = []
    with open(filename, "r") as f:
        reader = csv.DictReader(f)
        #skipping the extra metadata
        for i in range(3):
            l = next(reader)
        # processing file
        for line in reader:
            # calling your function to fix the area value
            if "name" in line:
                line["name"] = fix_name(line["name"])
            data.append(line)
    return data


def test():
    data = process_file(CITIES)

    print("Printing 20 results:")
    for n in range(20):
        pprint.pprint(data[n]["name"])

    assert data[14]["name"] == ['Negtemiut', 'Nightmute']
    assert data[9]["name"] == ['Pell City Alabama']
    assert data[3]["name"] == ['Kumhari']

if __name__ == "__main__":
    test()
# Out:
# Printing 20 results:
# ['Kud']
# ['Kuju']
# ['Kumbhraj']
# ['Kumhari']
# ['Kundagola', 'Kundgol ಕುಂದಗೋಳ']
# ['Kunigal']
# ['Kunzer']
# ['Kurduvadi', 'कुर्डुवाडी']
# ['Kurgunta']
# ['Kurinjipadi']
# ['Kurud']
# ['Kushtagi']
# ['Ladnun', 'लाडनूँ']
# ['Lahar', 'लहार']
# ['Laharpur']
# ['Lakheri']
# ['Lakhipur']
# ['Laksar', 'लक्सर']
# ['Lalkuan']
# ['Lalsot']
# ['Laharpur']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-298-f37dcfc617c4> in <module>()
#      70
#      71 if __name__ == "__main__":
# ---> 72     test()
#
# <ipython-input-298-f37dcfc617c4> in test()
#      65         pprint.pprint(data[n]["name"])
#      66     print(data[14]["name"])
# ---> 67     assert data[14]["name"] == ['Negtemiut', 'Nightmute']
#      68     assert data[9]["name"] == ['Pell City Alabama']
#      69     assert data[3]["name"] == ['Kumhari']
#
# AssertionError:

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up.

If you look at the full city data, you will notice that there are couple of
values that seem to provide the same information in different formats: "point"
seems to be the combination of "wgs84_pos#lat" and "wgs84_pos#long". However,
we do not know if that is the case and should check if they are equivalent.

Finish the function check_loc(). It will recieve 3 strings: first, the combined
value of "point" followed by the separate "wgs84_pos#" values. You have to
extract the lat and long values from the "point" argument and compare them to
the "wgs84_pos# values, returning True or False.

Note that you do not have to fix the values, only determine if they are
consistent. To fix them in this case you would need more information. Feel free
to discuss possible strategies for fixing this on the discussion forum.

The rest of the code is just an example on how this function can be used.
Changes to "process_file" function will not be taken into account for grading.
"""
import csv
import pprint

CITIES = 'cities.csv'


def check_loc(point, lat, longi):
    # YOUR CODE HERE
    point = point.split(" ")
   
    if (point[0] == lat) and (point[1] == longi):
        return True
    else: 
        return False


def process_file(filename):
    data = []
    with open(filename, "r") as f:
        reader = csv.DictReader(f)
        #skipping the extra matadata
        for i in range(3):
            l = reader.next()
        # processing file
        for line in reader:
            # calling your function to check the location
            result = check_loc(line["point"], line["wgs84_pos#lat"], line["wgs84_pos#long"])
            if not result:
                print("{}: {} != {} {}".format(line["name"], line["point"], line["wgs84_pos#lat"], line["wgs84_pos#long"]))
            data.append(line)

    return data


def test():
    assert check_loc("33.08 75.28", "33.08", "75.28") == True
    assert check_loc("44.57833333333333 -91.21833333333333", "44.5783", "-91.2183") == False

if __name__ == "__main__":
    test()
